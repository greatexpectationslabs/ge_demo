# %% [markdown]
# # NYC taxi trip data analysis
# Data: https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page
#
# Data dictionary: https://www1.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_yellow.pdf

# %%
from sqlalchemy import create_engine
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set()
conn_string = os.getenv('GE_DEMO_DB')

# %%
df_jan = pd.read_sql_table('yellow_tripdata_sample_2019_01', conn_string)
df_jan
# Out:
#      vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# 0            2 2019-01-05 06:36:51 2019-01-05 06:50:42              1.0
# 1            1 2019-01-23 15:22:13 2019-01-23 15:32:50              1.0
# 2            2 2019-01-04 10:54:47 2019-01-04 11:18:31              2.0
# 3            1 2019-01-05 12:07:08 2019-01-05 12:14:06              1.0
# 4            2 2019-01-04 18:23:00 2019-01-04 18:25:22              5.0
# ...        ...                 ...                 ...              ...
# 9995         2 2019-01-01 05:39:35 2019-01-01 06:04:19              1.0
# 9996         2 2019-01-31 14:23:02 2019-01-31 14:35:24              1.0
# 9997         1 2019-01-24 13:08:20 2019-01-24 13:30:16              1.0
# 9998         2 2019-01-24 07:29:50 2019-01-25 06:39:33              1.0
# 9999         2 2019-01-12 01:22:17 2019-01-12 01:33:08              5.0
#
#       trip_distance rate_code_id store_and_fwd_flag  pickup_location_id  \
# 0              3.72            1                  N                68.0
# 1              3.30            1                  N                12.0
# 2              3.09            1                  N               234.0
# 3              1.00            1                  N                25.0
# 4              0.41            1                  N               151.0
# ...             ...          ...                ...                 ...
# 9995          16.50            2                  N               162.0
# 9996           1.17            1                  N               170.0
# 9997           2.10            1                  N               170.0
# 9998           1.38            1                  N               249.0
# 9999           2.08            1                  N               113.0
#
#       dropoff_location_id payment_type  fare_amount  extra  mta_tax  \
# 0                   236.0            1         14.0    0.0      0.5
# 1                   232.0            2         12.5    0.0      0.5
# 2                   236.0            1         17.0    0.0      0.5
# 3                    49.0            1          6.0    0.0      0.5
# 4                   151.0            1          3.5    1.0      0.5
# ...                   ...          ...          ...    ...      ...
# 9995                132.0            1         52.0    0.0      0.5
# 9996                230.0            1          9.0    0.0      0.5
# 9997                249.0            1         14.0    0.0      0.5
# 9998                186.0            1          7.5    0.0      0.5
# 9999                246.0            1          9.5    0.5      0.5
#
#       tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0           1.00          0.00                    0.3         15.80
# 1           0.00          0.00                    0.3         13.30
# 2           3.56          0.00                    0.3         21.36
# 3           1.35          0.00                    0.3          8.15
# 4           0.80          0.00                    0.3          6.10
# ...          ...           ...                    ...           ...
# 9995       11.71          5.76                    0.3         70.27
# 9996        2.45          0.00                    0.3         12.25
# 9997        1.00          0.00                    0.3         15.80
# 9998        1.00          0.00                    0.3          9.30
# 9999        2.16          0.00                    0.3         12.96
#
#       congestion_surcharge
# 0                      NaN
# 1                      0.0
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 9995                   NaN
# 9996                   0.0
# 9997                   0.0
# 9998                   0.0
# 9999                   NaN
#
# [10000 rows x 18 columns]

# %%
plt.rcParams['figure.figsize'] = [7,6]

def plot_passenger_count(df):
    label_size = 18
    tick_size = 14
    sns.distplot(df[['passenger_count']], bins=7, kde=False)
#     plt.ylabel('Number of taxi rides', size=label_size)
#     plt.xlabel('Number of passengers per taxi ride', size=label_size)
    plt.xticks(size=tick_size)
    plt.yticks(size=tick_size)
    plt.ylim(0, 7600)
    plt.show()
    
plot_passenger_count(df_jan)

# %%
df_feb = pd.read_sql_table('yellow_tripdata_staging', conn_string)
plot_passenger_count(df_feb)
