# %% [markdown]
# # NYC taxi trip data analysis
# Data: https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page
#
# Data dictionary: https://www1.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_yellow.pdf

# %%
from sqlalchemy import create_engine
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = [10,5]
sns.set()
conn_string = os.getenv('GE_DEMO_DB')

def plot_passenger_count(df):
    sns.distplot(df[['passenger_count']], bins=6, kde=False)
    plt.title('Passenger count frequency')
    plt.ylabel('')
    plt.xlabel('Number of passengers per ride')
    plt.show()

# %%
df_jan = pd.read_sql_table('yellow_tripdata_sample_2019_01', conn_string)
df_jan.T
# Out:
#                                       0                    1     \
# vendor_id                                2                    1
# pickup_datetime        2019-01-05 06:36:51  2019-01-23 15:22:13
# dropoff_datetime       2019-01-05 06:50:42  2019-01-23 15:32:50
# passenger_count                          1                    1
# trip_distance                         3.72                  3.3
# rate_code_id                             1                    1
# store_and_fwd_flag                       N                    N
# pickup_location_id                      68                   12
# dropoff_location_id                    236                  232
# payment_type                             1                    2
# fare_amount                             14                 12.5
# extra                                    0                    0
# mta_tax                                0.5                  0.5
# tip_amount                               1                    0
# tolls_amount                             0                    0
# improvement_surcharge                  0.3                  0.3
# total_amount                          15.8                 13.3
# congestion_surcharge                   NaN                    0
#
#                                       2                    3     \
# vendor_id                                2                    1
# pickup_datetime        2019-01-04 10:54:47  2019-01-05 12:07:08
# dropoff_datetime       2019-01-04 11:18:31  2019-01-05 12:14:06
# passenger_count                          2                    1
# trip_distance                         3.09                    1
# rate_code_id                             1                    1
# store_and_fwd_flag                       N                    N
# pickup_location_id                     234                   25
# dropoff_location_id                    236                   49
# payment_type                             1                    1
# fare_amount                             17                    6
# extra                                    0                    0
# mta_tax                                0.5                  0.5
# tip_amount                            3.56                 1.35
# tolls_amount                             0                    0
# improvement_surcharge                  0.3                  0.3
# total_amount                         21.36                 8.15
# congestion_surcharge                   NaN                  NaN
#
#                                       4                    5     \
# vendor_id                                2                    1
# pickup_datetime        2019-01-04 18:23:00  2019-01-06 10:52:46
# dropoff_datetime       2019-01-04 18:25:22  2019-01-06 11:08:39
# passenger_count                          5                    2
# trip_distance                         0.41                  3.3
# rate_code_id                             1                    5
# store_and_fwd_flag                       N                    N
# pickup_location_id                     151                  144
# dropoff_location_id                    151                  161
# payment_type                             1                    1
# fare_amount                            3.5                   15
# extra                                    1                    0
# mta_tax                                0.5                    0
# tip_amount                             0.8                    0
# tolls_amount                             0                    0
# improvement_surcharge                  0.3                  0.3
# total_amount                           6.1                 15.3
# congestion_surcharge                   NaN                  NaN
#
#                                       6                    7     \
# vendor_id                                2                    2
# pickup_datetime        2019-01-22 18:26:28  2019-01-20 23:03:56
# dropoff_datetime       2019-01-22 18:35:38  2019-01-20 23:21:49
# passenger_count                          1                    1
# trip_distance                         1.69                 5.28
# rate_code_id                             1                    1
# store_and_fwd_flag                       N                    N
# pickup_location_id                     142                  114
# dropoff_location_id                    238                  239
# payment_type                             1                    1
# fare_amount                              8                   18
# extra                                    1                  0.5
# mta_tax                                0.5                  0.5
# tip_amount                             1.2                 3.86
# tolls_amount                             0                    0
# improvement_surcharge                  0.3                  0.3
# total_amount                            11                23.16
# congestion_surcharge                     0                  NaN
#
#                                       8                    9     ...  \
# vendor_id                                2                    1  ...
# pickup_datetime        2019-01-23 00:17:10  2019-01-28 12:58:13  ...
# dropoff_datetime       2019-01-23 00:32:58  2019-01-28 13:47:02  ...
# passenger_count                          1                    1  ...
# trip_distance                         2.75                 12.1  ...
# rate_code_id                             1                    1  ...
# store_and_fwd_flag                       N                    N  ...
# pickup_location_id                     161                  236  ...
# dropoff_location_id                     79                  138  ...
# payment_type                             1                    1  ...
# fare_amount                           12.5                   43  ...
# extra                                  0.5                    0  ...
# mta_tax                                0.5                  0.5  ...
# tip_amount                            2.76                 10.9  ...
# tolls_amount                             0                    0  ...
# improvement_surcharge                  0.3                  0.3  ...
# total_amount                         16.56                 54.7  ...
# congestion_surcharge                     0                    0  ...
#
#                                       9990                 9991  \
# vendor_id                                1                    1
# pickup_datetime        2019-01-14 18:12:31  2019-01-28 07:22:30
# dropoff_datetime       2019-01-14 18:33:56  2019-01-28 07:30:37
# passenger_count                          1                    1
# trip_distance                          2.6                  1.7
# rate_code_id                             1                    1
# store_and_fwd_flag                       N                    N
# pickup_location_id                     264                  186
# dropoff_location_id                    264                  161
# payment_type                             2                    2
# fare_amount                             15                    8
# extra                                    1                    0
# mta_tax                                0.5                  0.5
# tip_amount                               0                    0
# tolls_amount                             0                    0
# improvement_surcharge                  0.3                  0.3
# total_amount                          16.8                  8.8
# congestion_surcharge                   NaN                    0
#
#                                       9992                 9993  \
# vendor_id                                1                    1
# pickup_datetime        2019-01-11 16:20:27  2019-01-07 18:25:46
# dropoff_datetime       2019-01-11 16:28:41  2019-01-07 18:38:28
# passenger_count                          1                    1
# trip_distance                          0.6                  1.7
# rate_code_id                             1                    1
# store_and_fwd_flag                       N                    N
# pickup_location_id                     164                  237
# dropoff_location_id                    234                  262
# payment_type                             1                    1
# fare_amount                              7                    9
# extra                                    1                    1
# mta_tax                                0.5                  0.5
# tip_amount                            1.75                 2.15
# tolls_amount                             0                    0
# improvement_surcharge                  0.3                  0.3
# total_amount                         10.55                12.95
# congestion_surcharge                   NaN                  NaN
#
#                                       9994                 9995  \
# vendor_id                                1                    1
# pickup_datetime        2019-01-14 09:04:21  2019-01-22 15:05:04
# dropoff_datetime       2019-01-14 09:06:59  2019-01-22 15:15:49
# passenger_count                          1                    1
# trip_distance                          0.5                  1.1
# rate_code_id                             1                    1
# store_and_fwd_flag                       N                    N
# pickup_location_id                     162                  261
# dropoff_location_id                    163                  231
# payment_type                             2                    2
# fare_amount                              4                    8
# extra                                    0                    0
# mta_tax                                0.5                  0.5
# tip_amount                               0                    0
# tolls_amount                             0                    0
# improvement_surcharge                  0.3                  0.3
# total_amount                           4.8                  8.8
# congestion_surcharge                   NaN                    0
#
#                                       9996                 9997  \
# vendor_id                                1                    1
# pickup_datetime        2019-01-14 08:47:03  2019-01-21 13:38:03
# dropoff_datetime       2019-01-14 09:13:05  2019-01-21 13:42:05
# passenger_count                          1                    1
# trip_distance                          2.5                  0.6
# rate_code_id                             1                    1
# store_and_fwd_flag                       N                    N
# pickup_location_id                     237                  237
# dropoff_location_id                    107                  237
# payment_type                             2                    2
# fare_amount                           16.5                    5
# extra                                    0                    0
# mta_tax                                0.5                  0.5
# tip_amount                               0                    0
# tolls_amount                             0                    0
# improvement_surcharge                  0.3                  0.3
# total_amount                          17.3                  5.8
# congestion_surcharge                   NaN                    0
#
#                                       9998                 9999
# vendor_id                                1                    1
# pickup_datetime        2019-01-25 19:24:39  2019-01-11 14:31:37
# dropoff_datetime       2019-01-25 19:35:29  2019-01-11 14:51:51
# passenger_count                          1                    1
# trip_distance                          1.4                    2
# rate_code_id                             1                    1
# store_and_fwd_flag                       N                    N
# pickup_location_id                     230                  264
# dropoff_location_id                    143                  264
# payment_type                             1                    1
# fare_amount                            8.5                   14
# extra                                    1                    0
# mta_tax                                0.5                  0.5
# tip_amount                            2.55                 2.95
# tolls_amount                             0                    0
# improvement_surcharge                  0.3                  0.3
# total_amount                         12.85                17.75
# congestion_surcharge                     0                  NaN
#
# [18 rows x 10000 columns]

# %%
plot_passenger_count(df_jan)

# %%
df_feb = pd.read_sql_table('yellow_tripdata_latest', conn_string)
plot_passenger_count(df_feb)
